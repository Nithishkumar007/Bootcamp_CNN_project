# %%
import tensorflow as tf
from tensorflow import keras
import numpy as n

# %%
fashion_mnist=keras.datasets.fashion_mnist

# %%
(train_images,train_labels),(test_images,test_labels)=fashion_mnist.load_data()

# %%
train_images=train_images/255.0
test_images=test_images/255.0

# %%
train_images[0].shape
# Out:
# (28, 28)

# %%
train_images[0].shape
# Out:
# (28, 28)

# %%
train_images=train_images.reshape(len(train_images),28,28,1)
test_images=test_images.reshape(len(test_images),28,28,1)

# %%
def build_model(hp):
    model=keras.Sequential([
      keras.layers.Conv2D(
        filters=hp.Int('conv_1_filter',min_value=32,max_value=128,step=16),
        kernel_size=hp.Choice('conv_1_kernel',values=[3,5]),
        activation='relu',
        input_shape=(28,28,1)
      ),
      keras.layers.Conv2D(
          filters=hp.Int('conv_2_filter',min_value=32,max_value=64,step=16),
          kernel_size=hp.Choice('conv_2_kernel',values=[3,5]),
          activation='relu',
      ),
      keras.layers.Flatten(),
      keras.layers.Dense(
          units=hp.Int('dense_1_units',min_value=32,max_value=128,step=16),
          activation='relu'
      ),
      keras.layers.Dense(10,activation='softmax')
    ])
    model.compile(optimizer=keras.optimizers.Adam(hp.Choice('learning_rate', values=[1e-2,1e-3])),
          loss='sparse_categorical_crossentropy',
          metrics=['accuracy'])
    return model

# %%
# !pip install -q -U keras-tuner

# %%
from kerastuner import RandomSearch
from kerastuner.engine.hyperparameters import HyperParameters

# %%
tuner_search = RandomSearch( build_model, objective='val_accuracy', 
                     max_trials=5, directory='output',project_name="Mnist Fashion")

# %%
tuner_search.search(train_images,train_labels,epochs=3,validation_split=0.1)
# Out:
# Trial 1 Complete [00h 18m 22s]
# val_accuracy: 0.9104999899864197
#
# Best val_accuracy So Far: 0.9104999899864197
# Total elapsed time: 00h 18m 22s
#
# Search: Running Trial #2
#
# Hyperparameter    |Value             |Best Value So Far
# conv_1_filter     |32                |112
# conv_1_kernel     |3                 |3
# conv_2_filter     |48                |64
# conv_2_kernel     |5                 |3
# dense_1_units     |112               |80
# learning_rate     |0.01              |0.001
#
# Epoch 1/3
# 1688/1688 [==============================] - 217s 128ms/step - loss: 0.4684 - accuracy: 0.8342 - val_loss: 0.3598 - val_accuracy: 0.8737
# Epoch 2/3
# 1688/1688 [==============================] - 219s 129ms/step - loss: 0.3475 - accuracy: 0.8721 - val_loss: 0.3570 - val_accuracy: 0.8685
# Epoch 3/3
#  852/1688 [==============>...............] - ETA: 1:45 - loss: 0.2981 - accuracy: 0.8885

# %%
model=tuner_search.get_best_models(num_models=1)[0]

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 24, 24, 128)       3328
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 22, 22, 48)        55344
# _________________________________________________________________
# flatten (Flatten)            (None, 23232)             0
# _________________________________________________________________
# dense (Dense)                (None, 112)               2602096
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1130
# =================================================================
# Total params: 2,661,898
# Trainable params: 2,661,898
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Thanks for your BOOTCAMP session on CNN model. 
#It is very usefull one many new things we have learnt.
#N.Nithish Kumar,Department of Computer Technology,Dr.N.G.P. Arts and Science College,Coimbatore.
